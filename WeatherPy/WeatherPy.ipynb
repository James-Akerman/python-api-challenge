# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
from pprint import pprint
import numpy as np
from citipy import citipy
weather_api_key = ""

# %% [markdown]
# ## Generate Cities List

# %%
#  Inspiration: Ivana Stopka
# Specify range of Latitudes and Longitudes
lat_range = (-90, 90)
long_range = (-180, 180)

# Create two lists for holding lat_longs and cities
lat_lng = []
world_cities_list = []

# Set the 
np.random.seed(0)

# Create a set of random lat and long combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs_tuple = zip(lats, lngs)

#Find the nearest city for each combination of latitude and longitutde
for lat_lng in lat_lngs_tuple:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, append to the cities list
    if city not in world_cities_list:
        world_cities_list.append(city)

# Convert from a tuple to a list
world_cities_list = list(world_cities_list)
# Segment the list
world_cities_list_seg = np.array_split(world_cities_list,15)
# Out:
# 15

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "api.openweathermap.org/data/2.5/weather?q="
city_number = 1

name_list, lon_list, lat_list, temp_max_list, humidity_list = ([] for i in range(5))
cloudiness_list, windspeed_list, country_list, date_list = ([] for i in range(4))


print("Beginning Data Retrieval")     
print("-----------------------------")
for set_id in range(0,len(world_cities_list_seg)):
    for city in world_cities_list_seg[set_id]:
        try: 
            response = requests.get("https://" + url + city + "&appid=" + weather_api_key).json()
            # Log Output
            print(f"Processing Record {city_number} of Set {set_id + 1} | {response['name']}")
            # Add all values to the directory
            name_list.append(response["name"])
            lon_list.append(response["coord"]["lon"])
            lat_list.append(response["coord"]["lat"])
            temp_max_list.append(response["main"]["temp_max"])
            humidity_list.append(response["main"]["humidity"])
            cloudiness_list.append(response["clouds"]["all"])
            windspeed_list.append(response["wind"]["speed"])
            country_list.append(response["sys"]["country"])
            date_list.append(response["dt"])
            city_number += 1
        except:
            print("City not found. Skipping...")
    
    #Reset City Number
    city_number = 1

print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 1 of Set 1 | Vendas Novas
# Processing Record 2 of Set 1 | Arlit
# Processing Record 3 of Set 1 | Santa Cruz de la Sierra
# Processing Record 4 of Set 1 | Montepuez
# Processing Record 5 of Set 1 | Cockburn Town
# Processing Record 6 of Set 1 | Lubumbashi
# Processing Record 7 of Set 1 | Yellowknife
# Processing Record 8 of Set 1 | Tuktoyaktuk
# Processing Record 9 of Set 1 | Caravelas
# Processing Record 10 of Set 1 | Grindavik
# City not found. Skipping...
# Processing Record 11 of Set 1 | Atuona
# Processing Record 12 of Set 1 | Barrow
# Processing Record 13 of Set 1 | Vaini
# Processing Record 14 of Set 1 | Ushuaia
# Processing Record 15 of Set 1 | Cape Town
# Processing Record 16 of Set 1 | Kargasok
# Processing Record 17 of Set 1 | Skibbereen
# Processing Record 18 of Set 1 | Belaya Gora
# Processing Record 19 of Set 1 | Barrhead
# Processing Record 20 of Set 1 | Jacareacanga
# Processing Record 21 of Set 1 | Dovbysh
# Processing Record 22 of Set 1 | New Norfolk
# Processing Record 23 of Set 1 | Codrington
# Processing Record 24 of Set 1 | Punta Arenas
# Processing Record 25 of Set 1 | Limbang
# Processing Record 26 of Set 1 | Janaúba
# Processing Record 27 of Set 1 | Kruisfontein
# Processing Record 28 of Set 1 | Nikolskoye
# City not found. Skipping...
# Processing Record 29 of Set 1 | Constitución
# Processing Record 30 of Set 1 | Albany
# Processing Record 31 of Set 1 | Suicheng
# Processing Record 32 of Set 1 | Loikaw
# Processing Record 33 of Set 1 | Bilma
# Processing Record 34 of Set 1 | Pevek
# Processing Record 35 of Set 1 | Ribeira Grande
# Processing Record 36 of Set 1 | Inhambane
# Processing Record 37 of Set 1 | Faanui
# Processing Record 38 of Set 1 | Busselton
# Processing Record 39 of Set 1 | Nederland
# City not found. Skipping...
# Processing Record 40 of Set 1 | Saint-Philippe
# Processing Record 41 of Set 1 | Geraldton
# Processing Record 42 of Set 1 | Mataura
# Processing Record 43 of Set 1 | Butaritari
# City not found. Skipping...
# Processing Record 44 of Set 1 | Chokurdakh
# Processing Record 1 of Set 2 | Pascagoula
# Processing Record 2 of Set 2 | Soyo
# Processing Record 3 of Set 2 | Rikitea
# Processing Record 4 of Set 2 | Mar del Plata
# Processing Record 5 of Set 2 | Jalu
# City not found. Skipping...
# Processing Record 6 of Set 2 | Jamestown
# Processing Record 7 of Set 2 | Nanortalik
# Processing Record 8 of Set 2 | Yerbogachën
# City not found. Skipping...
# Processing Record 9 of Set 2 | Gamba
# City not found. Skipping...
# Processing Record 10 of Set 2 | Bethel
# Processing Record 11 of Set 2 | East London
# Processing Record 12 of Set 2 | Mahébourg
# Processing Record 13 of Set 2 | Karpathos
# Processing Record 14 of Set 2 | Trincomalee
# Processing Record 15 of Set 2 | Bhatkal
# Processing Record 16 of Set 2 | Ilulissat
# Processing Record 17 of Set 2 | Arraial do Cabo
# Processing Record 18 of Set 2 | Brenham
# Processing Record 19 of Set 2 | Severo-Kuril'sk
# Processing Record 20 of Set 2 | Lebu
# Processing Record 21 of Set 2 | Bara
# Processing Record 22 of Set 2 | Stornoway
# Processing Record 23 of Set 2 | Hillsboro
# Processing Record 24 of Set 2 | Pitsunda
# Processing Record 25 of Set 2 | Longyearbyen
# Processing Record 26 of Set 2 | Waitati
# Processing Record 27 of Set 2 | Kavaratti
# Processing Record 28 of Set 2 | Palāsa
# Processing Record 29 of Set 2 | Cidreira
# Processing Record 30 of Set 2 | Upernavik
# Processing Record 31 of Set 2 | Siloam Springs
# City not found. Skipping...
# Processing Record 32 of Set 2 | Opuwo
# City not found. Skipping...
# Processing Record 33 of Set 2 | Palauig
# Processing Record 34 of Set 2 | Thompson
# Processing Record 35 of Set 2 | Saint George
# Processing Record 36 of Set 2 | At-Bashi
# Processing Record 37 of Set 2 | Itarema
# City not found. Skipping...
# Processing Record 38 of Set 2 | Los Llanos de Aridane
# Processing Record 39 of Set 2 | Cairns
# Processing Record 40 of Set 2 | Ponta do Sol
# Processing Record 41 of Set 2 | Whitianga
# City not found. Skipping...
# Processing Record 42 of Set 2 | Chui
# Processing Record 1 of Set 3 | Hilo
# City not found. Skipping...
# Processing Record 2 of Set 3 | Ulladulla
# Processing Record 3 of Set 3 | Acapulco de Juárez
# Processing Record 4 of Set 3 | Kattivākkam
# Processing Record 5 of Set 3 | Valentín Gómez Farías
# Processing Record 6 of Set 3 | Guerrero Negro
# Processing Record 7 of Set 3 | Rodrigues Alves
# Processing Record 8 of Set 3 | Saskylakh
# Processing Record 9 of Set 3 | Walvis Bay
# Processing Record 10 of Set 3 | Husavik
# Processing Record 11 of Set 3 | Lebyazh'ye
# Processing Record 12 of Set 3 | Licata
# Processing Record 13 of Set 3 | Bredasdorp
# Processing Record 14 of Set 3 | Dandong
# Processing Record 15 of Set 3 | Souillac
# Processing Record 16 of Set 3 | Yangi Marg`ilon
# Processing Record 17 of Set 3 | Naze
# Processing Record 18 of Set 3 | Nome
# Processing Record 19 of Set 3 | Dukhovshchina
# Processing Record 20 of Set 3 | Kralendijk
# Processing Record 21 of Set 3 | Huarmey
# Processing Record 22 of Set 3 | Hithadhoo
# City not found. Skipping...
# Processing Record 23 of Set 3 | Tura
# Processing Record 24 of Set 3 | Kysyl-Syr
# Processing Record 25 of Set 3 | Vila Velha
# Processing Record 26 of Set 3 | Bluff
# Processing Record 27 of Set 3 | Provideniya
# Processing Record 28 of Set 3 | Bambous Virieux
# Processing Record 29 of Set 3 | Qaanaaq
# Processing Record 30 of Set 3 | Hobart
# Processing Record 31 of Set 3 | Kapaa
# Processing Record 32 of Set 3 | Kutum
# Processing Record 33 of Set 3 | Coyhaique
# Processing Record 34 of Set 3 | Tiksi
# Processing Record 35 of Set 3 | Riyadh
# Processing Record 36 of Set 3 | Meïganga
# Processing Record 37 of Set 3 | Provincia di Campobasso
# City not found. Skipping...
# Processing Record 38 of Set 3 | Poum
# Processing Record 39 of Set 3 | Port Elizabeth
# Processing Record 40 of Set 3 | Zhangaözen
# Processing Record 41 of Set 3 | Port-Gentil
# Processing Record 42 of Set 3 | Portland
# Processing Record 43 of Set 3 | Laas
# Processing Record 44 of Set 3 | San Lazaro
# Processing Record 45 of Set 3 | Nālūt
# Processing Record 46 of Set 3 | Hong Kong
# Processing Record 1 of Set 4 | Namatanai
# Processing Record 2 of Set 4 | Kjøllefjord
# Processing Record 3 of Set 4 | Pisco
# Processing Record 4 of Set 4 | Barra Patuca
# Processing Record 5 of Set 4 | Rudnogorsk
# City not found. Skipping...
# Processing Record 6 of Set 4 | Hermanus
# Processing Record 7 of Set 4 | Cherskiy
# Processing Record 8 of Set 4 | Nemuro
# Processing Record 9 of Set 4 | Port Alfred
# Processing Record 10 of Set 4 | Río Gallegos
# Processing Record 11 of Set 4 | Boa Vista
# Processing Record 12 of Set 4 | Mórrope
# Processing Record 13 of Set 4 | Ouro Sogui
# Processing Record 14 of Set 4 | Zyryanka
# Processing Record 15 of Set 4 | Clarksburg
# Processing Record 16 of Set 4 | Capinópolis
# Processing Record 17 of Set 4 | Prachuap Khiri Khan
# Processing Record 18 of Set 4 | Kaeo
# Processing Record 19 of Set 4 | Dikson
# Processing Record 20 of Set 4 | Marfino
# Processing Record 21 of Set 4 | Saint Paul Harbor
# Processing Record 22 of Set 4 | Clyde River
# Processing Record 23 of Set 4 | Coahuayana Viejo
# Processing Record 24 of Set 4 | Pandan
# City not found. Skipping...
# Processing Record 25 of Set 4 | Pacific Grove
# Processing Record 26 of Set 4 | Kungurtug
# Processing Record 27 of Set 4 | Salinas
# Processing Record 28 of Set 4 | Narsaq
# Processing Record 29 of Set 4 | Rovaniemi
# Processing Record 30 of Set 4 | Broken Hill
# Processing Record 31 of Set 4 | Norman Wells
# Processing Record 32 of Set 4 | Mehamn
# Processing Record 33 of Set 4 | Dingle
# Processing Record 34 of Set 4 | Haicheng
# Processing Record 35 of Set 4 | Srednekolymsk
# Processing Record 36 of Set 4 | Oktyabr'skoye
# Processing Record 37 of Set 4 | Beihai
# Processing Record 38 of Set 4 | Vallenar
# Processing Record 39 of Set 4 | Angoram
# Processing Record 40 of Set 4 | Katsuura
# Processing Record 41 of Set 4 | Saint Anthony
# Processing Record 42 of Set 4 | Jacqueville
# Processing Record 43 of Set 4 | Dunedin
# Processing Record 44 of Set 4 | Pangnirtung
# Processing Record 45 of Set 4 | Krasnyy Chikoy
# Processing Record 46 of Set 4 | Kalach-na-Donu
# Processing Record 47 of Set 4 | Castro
# Processing Record 1 of Set 5 | Natitingou
# Processing Record 2 of Set 5 | Vestmanna
# Processing Record 3 of Set 5 | Ottumwa
# Processing Record 4 of Set 5 | Kaitangata
# Processing Record 5 of Set 5 | Esperance
# Processing Record 6 of Set 5 | Pitimbu
# Processing Record 7 of Set 5 | Wilmington
# Processing Record 8 of Set 5 | Sidi Ali
# Processing Record 9 of Set 5 | Victor Harbor
# City not found. Skipping...
# Processing Record 10 of Set 5 | Lac du Bonnet
# Processing Record 11 of Set 5 | Flagstaff
# Processing Record 12 of Set 5 | Zbarazh
# Processing Record 13 of Set 5 | Sinnamary
# Processing Record 14 of Set 5 | Mitsamiouli
# Processing Record 15 of Set 5 | Yerofey Pavlovich
# Processing Record 16 of Set 5 | São Filipe
# Processing Record 17 of Set 5 | Kahului
# Processing Record 18 of Set 5 | Puerto Ayora
# Processing Record 19 of Set 5 | Airai
# Processing Record 20 of Set 5 | Batemans Bay
# Processing Record 21 of Set 5 | George Town
# Processing Record 22 of Set 5 | Khatanga
# Processing Record 23 of Set 5 | Los Algarrobos
# Processing Record 24 of Set 5 | Itaueira
# Processing Record 25 of Set 5 | Klaksvík
# Processing Record 26 of Set 5 | Manono
# Processing Record 27 of Set 5 | Cedartown
# Processing Record 28 of Set 5 | Torbay
# Processing Record 29 of Set 5 | Shingū
# Processing Record 30 of Set 5 | Petropavlovsk-Kamchatskiy
# Processing Record 31 of Set 5 | Mayumba
# Processing Record 32 of Set 5 | Kamphaeng Phet
# Processing Record 33 of Set 5 | Mayo
# Processing Record 34 of Set 5 | Pochutla
# Processing Record 35 of Set 5 | Terrace
# Processing Record 36 of Set 5 | Province of Mantua
# Processing Record 37 of Set 5 | Denpasar
# Processing Record 38 of Set 5 | Iqaluit
# Processing Record 39 of Set 5 | Mount Isa
# Processing Record 40 of Set 5 | Havøysund
# Processing Record 41 of Set 5 | Ostrovnoy
# Processing Record 42 of Set 5 | Lata
# Processing Record 43 of Set 5 | Bucerías
# Processing Record 44 of Set 5 | Bengkulu
# Processing Record 45 of Set 5 | Avarua
# Processing Record 46 of Set 5 | Guiratinga
# Processing Record 47 of Set 5 | Sibolga
# Processing Record 48 of Set 5 | Tuatapere
# Processing Record 1 of Set 6 | Tezu
# Processing Record 2 of Set 6 | Amapá
# Processing Record 3 of Set 6 | Becerril
# Processing Record 4 of Set 6 | Cap Malheureux
# Processing Record 5 of Set 6 | Alofi
# Processing Record 6 of Set 6 | Ullapool
# Processing Record 7 of Set 6 | Carnarvon
# Processing Record 8 of Set 6 | Severnoye
# Processing Record 9 of Set 6 | Berlevåg
# Processing Record 10 of Set 6 | College
# Processing Record 11 of Set 6 | Margate
# Processing Record 12 of Set 6 | Port Lincoln
# Processing Record 13 of Set 6 | Iwade
# Processing Record 14 of Set 6 | Talnakh
# Processing Record 15 of Set 6 | Chiredzi
# City not found. Skipping...
# Processing Record 16 of Set 6 | Tilichiki
# Processing Record 17 of Set 6 | Sandnessjøen
# Processing Record 18 of Set 6 | Gofitskoye
# Processing Record 19 of Set 6 | Asheville
# Processing Record 20 of Set 6 | Lucapa
# Processing Record 21 of Set 6 | Banjar
# Processing Record 22 of Set 6 | Faya
# Processing Record 23 of Set 6 | Deputatsky
# Processing Record 24 of Set 6 | Bedelē
# Processing Record 25 of Set 6 | Coração de Jesus
# City not found. Skipping...
# Processing Record 26 of Set 6 | Banda Aceh
# Processing Record 27 of Set 6 | Kirovskiy
# Processing Record 28 of Set 6 | Noumea
# Processing Record 29 of Set 6 | Rapid Valley
# Processing Record 30 of Set 6 | Hondomachi-hondo
# Processing Record 31 of Set 6 | Marsala
# Processing Record 32 of Set 6 | Calabozo
# Processing Record 33 of Set 6 | Seoul
# Processing Record 34 of Set 6 | Laranjal Paulista
# Processing Record 35 of Set 6 | Ibrā’
# City not found. Skipping...
# Processing Record 36 of Set 6 | Camacha
# Processing Record 37 of Set 6 | Huzhou
# Processing Record 38 of Set 6 | Kiryat Gat
# Processing Record 39 of Set 6 | Cabo San Lucas
# Processing Record 40 of Set 6 | Nagahama
# Processing Record 41 of Set 6 | Bridlington
# Processing Record 42 of Set 6 | Nhulunbuy
# Processing Record 43 of Set 6 | Sarangani
# Processing Record 44 of Set 6 | Saint-Pierre
# Processing Record 45 of Set 6 | Mossamedes
# Processing Record 46 of Set 6 | Atar
# Processing Record 1 of Set 7 | Talāja
# Processing Record 2 of Set 7 | Takoradze
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 7 | Miracema do Tocantins
# Processing Record 4 of Set 7 | Dayong
# City not found. Skipping...
# Processing Record 5 of Set 7 | Tasiilaq
# Processing Record 6 of Set 7 | Sitka
# Processing Record 7 of Set 7 | Sørland
# Processing Record 8 of Set 7 | Taltal
# Processing Record 9 of Set 7 | Guangyuan
# Processing Record 10 of Set 7 | Anloga
# Processing Record 11 of Set 7 | Santa Cruz de Tenerife
# City not found. Skipping...
# Processing Record 12 of Set 7 | Bayburt
# Processing Record 13 of Set 7 | Taksimo
# Processing Record 14 of Set 7 | Baruun-Urt
# City not found. Skipping...
# Processing Record 15 of Set 7 | Richards Bay
# Processing Record 16 of Set 7 | Labuhan
# Processing Record 17 of Set 7 | Goderich
# Processing Record 18 of Set 7 | Emba
# Processing Record 19 of Set 7 | Mucuri
# Processing Record 20 of Set 7 | Beitbridge
# Processing Record 21 of Set 7 | Zliten
# Processing Record 22 of Set 7 | Turukhansk
# City not found. Skipping...
# Processing Record 23 of Set 7 | Salalah
# Processing Record 24 of Set 7 | Anadyr
# Processing Record 25 of Set 7 | Carauari
# Processing Record 26 of Set 7 | Buin
# Processing Record 27 of Set 7 | Skellefteå
# Processing Record 28 of Set 7 | Belmonte
# Processing Record 29 of Set 7 | Zarand
# Processing Record 30 of Set 7 | Florianópolis
# Processing Record 31 of Set 7 | Jinchang
# Processing Record 32 of Set 7 | Nouadhibou
# Processing Record 33 of Set 7 | Yantal'
# Processing Record 34 of Set 7 | Shaowu
# Processing Record 35 of Set 7 | Acaraú
# Processing Record 36 of Set 7 | Quatre Cocos
# Processing Record 37 of Set 7 | Grand Gaube
# Processing Record 38 of Set 7 | Ballina
# Processing Record 39 of Set 7 | Oneonta
# City not found. Skipping...
# Processing Record 40 of Set 7 | Los Alamos
# Processing Record 41 of Set 7 | Robertsport
# Processing Record 42 of Set 7 | Tebingtinggi
# Processing Record 1 of Set 8 | Kenai
# Processing Record 2 of Set 8 | Muyezerskiy
# Processing Record 3 of Set 8 | Kavieng
# Processing Record 4 of Set 8 | Prince Rupert
# Processing Record 5 of Set 8 | Mzimba
# Processing Record 6 of Set 8 | Kibre Mengist
# Processing Record 7 of Set 8 | Ivybridge
# Processing Record 8 of Set 8 | Avilés
# Processing Record 9 of Set 8 | Hofn
# City not found. Skipping...
# Processing Record 10 of Set 8 | Moscow
# Processing Record 11 of Set 8 | Garissa
# Processing Record 12 of Set 8 | Kieta
# Processing Record 13 of Set 8 | Safi
# Processing Record 14 of Set 8 | Necochea
# Processing Record 15 of Set 8 | Puerto Vallarta
# Processing Record 16 of Set 8 | Cockeysville
# City not found. Skipping...
# Processing Record 17 of Set 8 | San Rafael
# Processing Record 18 of Set 8 | Bubaque
# Processing Record 19 of Set 8 | Dunda
# Processing Record 20 of Set 8 | Luanda
# City not found. Skipping...
# Processing Record 21 of Set 8 | Henties Bay
# Processing Record 22 of Set 8 | Swan River
# Processing Record 23 of Set 8 | Barcelos
# Processing Record 24 of Set 8 | Östersund
# Processing Record 25 of Set 8 | São Miguel do Araguaia
# Processing Record 26 of Set 8 | Solnechnyy
# Processing Record 27 of Set 8 | Port Keats
# Processing Record 28 of Set 8 | Port Blair
# Processing Record 29 of Set 8 | Alugan
# Processing Record 30 of Set 8 | Yar-Sale
# Processing Record 31 of Set 8 | Neiafu
# Processing Record 32 of Set 8 | Key Biscayne
# City not found. Skipping...
# Processing Record 33 of Set 8 | Sakaiminato
# Processing Record 34 of Set 8 | Vao
# Processing Record 35 of Set 8 | Saint-Félicien
# Processing Record 36 of Set 8 | Tateyama
# Processing Record 37 of Set 8 | Otorohanga
# Processing Record 38 of Set 8 | Prado
# Processing Record 39 of Set 8 | Olovo
# Processing Record 40 of Set 8 | Amuntai
# Processing Record 41 of Set 8 | Olafsvik
# Processing Record 42 of Set 8 | Bathsheba
# Processing Record 43 of Set 8 | Bereket
# Processing Record 44 of Set 8 | Guamúchil
# Processing Record 45 of Set 8 | Arawa
# Processing Record 1 of Set 9 | Leningradskiy
# Processing Record 2 of Set 9 | Coihueco
# Processing Record 3 of Set 9 | Placerville
# Processing Record 4 of Set 9 | Serebryanyy Bor
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 9 | Trairi
# Processing Record 6 of Set 9 | Fortuna
# Processing Record 7 of Set 9 | Buala
# Processing Record 8 of Set 9 | Hervey Bay
# Processing Record 9 of Set 9 | Neuquén
# Processing Record 10 of Set 9 | Avera
# Processing Record 11 of Set 9 | Santa Fe
# Processing Record 12 of Set 9 | Paso de los Toros
# Processing Record 13 of Set 9 | Kroya
# City not found. Skipping...
# Processing Record 14 of Set 9 | Khovu-Aksy
# Processing Record 15 of Set 9 | Likasi
# Processing Record 16 of Set 9 | Macas
# Processing Record 17 of Set 9 | Dharmapuri
# Processing Record 18 of Set 9 | Makkah al Mukarramah
# Processing Record 19 of Set 9 | Thinadhoo
# Processing Record 20 of Set 9 | Pontes e Lacerda
# Processing Record 21 of Set 9 | Bilibino
# Processing Record 22 of Set 9 | Aklavik
# Processing Record 23 of Set 9 | Laguna
# Processing Record 24 of Set 9 | Inuvik
# Processing Record 25 of Set 9 | Yulara
# Processing Record 26 of Set 9 | Beloha
# Processing Record 27 of Set 9 | Pasco
# Processing Record 28 of Set 9 | Malakal
# City not found. Skipping...
# Processing Record 29 of Set 9 | Port Alberni
# Processing Record 30 of Set 9 | Ambon City
# Processing Record 31 of Set 9 | Ust'-Kishert'
# Processing Record 32 of Set 9 | Arbroath
# Processing Record 33 of Set 9 | Ahipara
# Processing Record 34 of Set 9 | Coquimbo
# Processing Record 35 of Set 9 | Nizhniye Sergi
# Processing Record 36 of Set 9 | Tual
# Processing Record 37 of Set 9 | Lethem
# Processing Record 38 of Set 9 | Khandyga
# Processing Record 39 of Set 9 | Maneromango
# Processing Record 40 of Set 9 | Zhigansk
# Processing Record 41 of Set 9 | Marystown
# Processing Record 42 of Set 9 | Manta
# Processing Record 43 of Set 9 | Bensonville
# Processing Record 44 of Set 9 | Raudeberg
# Processing Record 45 of Set 9 | Vranov nad Dyjí
# Processing Record 1 of Set 10 | Biak
# Processing Record 2 of Set 10 | Canandaigua
# Processing Record 3 of Set 10 | Nola
# Processing Record 4 of Set 10 | Darya Khan
# Processing Record 5 of Set 10 | Tarakan
# Processing Record 6 of Set 10 | Ginda
# Processing Record 7 of Set 10 | Windsor
# Processing Record 8 of Set 10 | Bārmer
# City not found. Skipping...
# Processing Record 9 of Set 10 | Esim
# Processing Record 10 of Set 10 | Mahibadhoo
# Processing Record 11 of Set 10 | Rosario
# Processing Record 12 of Set 10 | Tainan City
# Processing Record 13 of Set 10 | Struthers
# Processing Record 14 of Set 10 | Lumeje
# Processing Record 15 of Set 10 | Tiznit Province
# Processing Record 16 of Set 10 | Vestmannaeyjar
# Processing Record 17 of Set 10 | Ancud
# Processing Record 18 of Set 10 | Hambantota
# Processing Record 19 of Set 10 | Kodinsk
# Processing Record 20 of Set 10 | Sheregesh
# Processing Record 21 of Set 10 | Malacca
# Processing Record 22 of Set 10 | Ternate
# Processing Record 23 of Set 10 | Shaunavon
# Processing Record 24 of Set 10 | Sisimiut
# Processing Record 25 of Set 10 | Dawlatabad
# City not found. Skipping...
# Processing Record 26 of Set 10 | Greater Sudbury
# Processing Record 27 of Set 10 | Beringovskiy
# Processing Record 28 of Set 10 | Kinsale
# Processing Record 29 of Set 10 | Buta
# Processing Record 30 of Set 10 | Alta Floresta
# Processing Record 31 of Set 10 | Lorengau
# Processing Record 32 of Set 10 | Teya
# Processing Record 33 of Set 10 | Nouakchott
# Processing Record 34 of Set 10 | Northam
# Processing Record 35 of Set 10 | San Quintín
# Processing Record 36 of Set 10 | Goshogawara
# Processing Record 37 of Set 10 | Ketchikan
# Processing Record 38 of Set 10 | Safford
# Processing Record 39 of Set 10 | Viedma
# Processing Record 40 of Set 10 | Gorontalo
# Processing Record 41 of Set 10 | Birecik
# Processing Record 42 of Set 10 | Assiut
# Processing Record 43 of Set 10 | Sioux Lookout
# Processing Record 44 of Set 10 | Znamenskoye
# Processing Record 45 of Set 10 | Shetpe
# Processing Record 46 of Set 10 | Dumabato
# Processing Record 47 of Set 10 | Daru
# Processing Record 1 of Set 11 | Uyuni
# Processing Record 2 of Set 11 | Matonga
# Processing Record 3 of Set 11 | Ridgecrest
# Processing Record 4 of Set 11 | Lüshunkou
# Processing Record 5 of Set 11 | Nkowakowa
# Processing Record 6 of Set 11 | Paamiut
# Processing Record 7 of Set 11 | Ranong
# Processing Record 8 of Set 11 | Quelimane
# Processing Record 9 of Set 11 | Flinders
# Processing Record 10 of Set 11 | Izhma
# Processing Record 11 of Set 11 | San Jerónimo
# City not found. Skipping...
# Processing Record 12 of Set 11 | Achit
# Processing Record 13 of Set 11 | Owando
# Processing Record 14 of Set 11 | Erzin
# Processing Record 15 of Set 11 | Masaya
# Processing Record 16 of Set 11 | Rome
# Processing Record 17 of Set 11 | Mutoko
# Processing Record 18 of Set 11 | Goryachegorsk
# Processing Record 19 of Set 11 | Kati
# City not found. Skipping...
# Processing Record 20 of Set 11 | Isangel
# Processing Record 21 of Set 11 | Puquio
# Processing Record 22 of Set 11 | Sept-Îles
# Processing Record 23 of Set 11 | Leh
# Processing Record 24 of Set 11 | Kherson
# Processing Record 25 of Set 11 | Dinard
# Processing Record 26 of Set 11 | Sorong
# Processing Record 27 of Set 11 | Saratov
# Processing Record 28 of Set 11 | Khovd
# Processing Record 29 of Set 11 | County Wicklow
# Processing Record 30 of Set 11 | Zalesovo
# Processing Record 31 of Set 11 | Kalmunai
# Processing Record 32 of Set 11 | De Aar
# Processing Record 33 of Set 11 | Karratha
# Processing Record 34 of Set 11 | Marsh Harbour
# Processing Record 35 of Set 11 | Sobolevo
# Processing Record 36 of Set 11 | Hīt
# Processing Record 37 of Set 11 | Keti Bandar
# Processing Record 38 of Set 11 | Gönc
# City not found. Skipping...
# Processing Record 39 of Set 11 | Vila
# Processing Record 40 of Set 11 | Adelaide
# Processing Record 41 of Set 11 | Shakawe
# Processing Record 42 of Set 11 | Tallahassee
# Processing Record 43 of Set 11 | Tsiroanomandidy
# Processing Record 44 of Set 11 | Tampakan
# Processing Record 45 of Set 11 | Wanaka
# Processing Record 46 of Set 11 | Virginia Beach
# Processing Record 1 of Set 12 | Nador
# Processing Record 2 of Set 12 | Antofagasta
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 12 | Rivière-du-Loup
# Processing Record 4 of Set 12 | Hamilton
# Processing Record 5 of Set 12 | Tottori-shi
# Processing Record 6 of Set 12 | Devils Lake
# Processing Record 7 of Set 12 | Knysna
# Processing Record 8 of Set 12 | Batticaloa
# City not found. Skipping...
# Processing Record 9 of Set 12 | Te Anau
# Processing Record 10 of Set 12 | Tārānagar
# Processing Record 11 of Set 12 | Boshnyakovo
# Processing Record 12 of Set 12 | Sault Ste. Marie
# Processing Record 13 of Set 12 | Gemena
# Processing Record 14 of Set 12 | Syracuse
# Processing Record 15 of Set 12 | Udachny
# Processing Record 16 of Set 12 | Kulhudhuffushi
# City not found. Skipping...
# Processing Record 17 of Set 12 | Kantunilkín
# Processing Record 18 of Set 12 | Bulgan
# Processing Record 19 of Set 12 | Lüderitz
# Processing Record 20 of Set 12 | Naranjito
# Processing Record 21 of Set 12 | Lavrentiya
# Processing Record 22 of Set 12 | Cravo Norte
# Processing Record 23 of Set 12 | Mount Gambier
# Processing Record 24 of Set 12 | Wanxian
# Processing Record 25 of Set 12 | Thakurgaon
# Processing Record 26 of Set 12 | Havelock
# Processing Record 27 of Set 12 | Šumatac
# Processing Record 28 of Set 12 | Rio Verde de Mato Grosso
# Processing Record 29 of Set 12 | Plettenberg Bay
# Processing Record 30 of Set 12 | Matara
# Processing Record 31 of Set 12 | Zhangye
# Processing Record 32 of Set 12 | Itacoatiara
# Processing Record 33 of Set 12 | Hurricane
# Processing Record 34 of Set 12 | Vilcún
# Processing Record 35 of Set 12 | Great Bend
# Processing Record 36 of Set 12 | Road Town
# Processing Record 37 of Set 12 | Saravena
# Processing Record 38 of Set 12 | Contamana
# Processing Record 39 of Set 12 | Ola
# Processing Record 40 of Set 12 | Erdenet
# Processing Record 41 of Set 12 | Along
# Processing Record 42 of Set 12 | Oranjemund
# Processing Record 43 of Set 12 | Teguise
# Processing Record 44 of Set 12 | Brownsville
# Processing Record 1 of Set 13 | Samarai
# Processing Record 2 of Set 13 | Bintulu
# Processing Record 3 of Set 13 | Arrifes
# Processing Record 4 of Set 13 | Bartica
# Processing Record 5 of Set 13 | Pinheiral
# City not found. Skipping...
# Processing Record 6 of Set 13 | Ambilobe
# City not found. Skipping...
# Processing Record 7 of Set 13 | Hasaki
# Processing Record 8 of Set 13 | Goundam
# Processing Record 9 of Set 13 | Bowen
# Processing Record 10 of Set 13 | Parksville
# Processing Record 11 of Set 13 | Genhe
# Processing Record 12 of Set 13 | São João da Barra
# Processing Record 13 of Set 13 | Melur
# Processing Record 14 of Set 13 | Chu
# Processing Record 15 of Set 13 | Hammerfest
# Processing Record 16 of Set 13 | Sanguéya
# Processing Record 17 of Set 13 | São José da Coroa Grande
# City not found. Skipping...
# Processing Record 18 of Set 13 | Vila Franca do Campo
# Processing Record 19 of Set 13 | Dongsheng
# Processing Record 20 of Set 13 | Fairbanks
# Processing Record 21 of Set 13 | Asopós
# Processing Record 22 of Set 13 | San Fernando del Valle de Catamarca
# Processing Record 23 of Set 13 | Havre-St-Pierre
# City not found. Skipping...
# Processing Record 24 of Set 13 | Ampanihy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 13 | Mudon
# Processing Record 26 of Set 13 | Mastic Beach
# Processing Record 27 of Set 13 | San Juan
# Processing Record 28 of Set 13 | Sukhumi
# Processing Record 29 of Set 13 | Lompoc
# Processing Record 30 of Set 13 | Knyaze-Volkonskoye
# Processing Record 31 of Set 13 | Fort Nelson
# Processing Record 32 of Set 13 | Chaiyaphum
# Processing Record 33 of Set 13 | Kaspiysk
# Processing Record 34 of Set 13 | Juneau
# City not found. Skipping...
# Processing Record 35 of Set 13 | Luganville
# Processing Record 36 of Set 13 | Xichang
# Processing Record 37 of Set 13 | Mīnāb
# Processing Record 38 of Set 13 | Taebla
# Processing Record 39 of Set 13 | Kishtwār
# Processing Record 40 of Set 13 | Tautira
# Processing Record 41 of Set 13 | Tiradentes
# Processing Record 1 of Set 14 | La Concordia
# Processing Record 2 of Set 14 | Muisne
# Processing Record 3 of Set 14 | Mujiayingzi
# Processing Record 4 of Set 14 | Shubarkuduk
# Processing Record 5 of Set 14 | Arona
# Processing Record 6 of Set 14 | Sergeevka
# Processing Record 7 of Set 14 | St. George's
# Processing Record 8 of Set 14 | Maumere
# Processing Record 9 of Set 14 | Prince George
# Processing Record 10 of Set 14 | Tupik
# Processing Record 11 of Set 14 | Gemeente Wageningen
# Processing Record 12 of Set 14 | Marrakesh
# Processing Record 13 of Set 14 | Maiduguri
# Processing Record 14 of Set 14 | Kerema
# Processing Record 15 of Set 14 | Les Cayes
# Processing Record 16 of Set 14 | Tambopata
# Processing Record 17 of Set 14 | Oodweyne
# Processing Record 18 of Set 14 | Half Moon Bay
# Processing Record 19 of Set 14 | Guarapari
# Processing Record 20 of Set 14 | Chara
# Processing Record 21 of Set 14 | Haines Junction
# Processing Record 22 of Set 14 | Qaqortoq
# Processing Record 23 of Set 14 | Ritchie
# Processing Record 24 of Set 14 | Kemlya
# Processing Record 25 of Set 14 | Sembakung
# Processing Record 26 of Set 14 | Nādāpuram
# Processing Record 27 of Set 14 | Maragogi
# Processing Record 28 of Set 14 | Maniitsoq
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 14 | Rawson
# Processing Record 30 of Set 14 | Nyalikungu
# Processing Record 31 of Set 14 | Saint-Augustin
# City not found. Skipping...
# Processing Record 32 of Set 14 | Iquique
# Processing Record 33 of Set 14 | Linqu
# Processing Record 34 of Set 14 | Gold Coast
# Processing Record 35 of Set 14 | Griffith
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 14 | San Patricio
# Processing Record 37 of Set 14 | Sur
# Processing Record 38 of Set 14 | Lienz
# Processing Record 39 of Set 14 | Luena
# Processing Record 40 of Set 14 | Talcahuano
# Processing Record 41 of Set 14 | Poronaysk
# City not found. Skipping...
# Processing Record 42 of Set 14 | Nizhniy Baskunchak
# Processing Record 1 of Set 15 | Moindou
# Processing Record 2 of Set 15 | Zemlyansk
# Processing Record 3 of Set 15 | Mayya
# Processing Record 4 of Set 15 | Jishou
# Processing Record 5 of Set 15 | Arman'
# Processing Record 6 of Set 15 | Muros
# Processing Record 7 of Set 15 | Agutaya
# Processing Record 8 of Set 15 | Puerto Escondido
# City not found. Skipping...
# Processing Record 9 of Set 15 | Makakilo City
# Processing Record 10 of Set 15 | Kunduz
# Processing Record 11 of Set 15 | High Level
# Processing Record 12 of Set 15 | Morelia
# Processing Record 13 of Set 15 | Līsakovsk
# Processing Record 14 of Set 15 | Caledon East
# Processing Record 15 of Set 15 | Bata
# Processing Record 16 of Set 15 | Marawi
# Processing Record 17 of Set 15 | Xining
# Processing Record 18 of Set 15 | Boende
# Processing Record 19 of Set 15 | Antón Lizardo
# Processing Record 20 of Set 15 | Iquitos
# Processing Record 21 of Set 15 | Storforshei
# Processing Record 22 of Set 15 | Alakurtti
# Processing Record 23 of Set 15 | Nishihara
# Processing Record 24 of Set 15 | Najrān
# Processing Record 25 of Set 15 | Loyga
# Processing Record 26 of Set 15 | Akureyri
# Processing Record 27 of Set 15 | Santa Maria
# Processing Record 28 of Set 15 | Niğde
# Processing Record 29 of Set 15 | Greensburg
# Processing Record 30 of Set 15 | Cumberland
# Processing Record 31 of Set 15 | Aste
# Processing Record 32 of Set 15 | North Bend
# Processing Record 33 of Set 15 | Tucupita
# Processing Record 34 of Set 15 | Rivadavia
# Processing Record 35 of Set 15 | Aden
# Processing Record 36 of Set 15 | Santiago
# Processing Record 37 of Set 15 | Nordfjordeid
# Processing Record 38 of Set 15 | Brae
# Processing Record 39 of Set 15 | Tena
# Processing Record 40 of Set 15 | Mopti
# Processing Record 41 of Set 15 | Kjøpsvik
# Processing Record 42 of Set 15 | Bathurst
# Processing Record 43 of Set 15 | Golden
# Processing Record 44 of Set 15 | Omboué
# Processing Record 45 of Set 15 | Alghero
# Processing Record 46 of Set 15 | Majene
# Processing Record 47 of Set 15 | Mitú
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_dict = {
    "City": name_list,
    "Lat": lat_list,
    "Lng": lon_list,
    "Max Temp": temp_max_list,
    "Humidity": humidity_list,
    "Cloudiness": cloudiness_list,
    "Wind Speed": windspeed_list,
    "Country": country_list,
    "Date": date_list
}
data = pd.DataFrame(city_dict)

data.to_csv("output/world_cities.csv",index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Import the data
new_data = pd.read_csv("output/world_cities.csv")
# Check if there are cities in the data with a humidity greater than 100%
cities_humidity_greater_100 = new_data.loc[(new_data["Humidity"] > 100)]
if (cities_humidity_greater_100.empty == True):
    print("There are no cities with humidity greater than 100%")
# Out:
# There are no cities with humidity greater than 100%

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
